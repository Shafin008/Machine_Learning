# %%
import pandas as pd
import requests

# %% [markdown]
# ### Javascript Object Notation (JSON)
#
# 1.Common web data format
#
# 2.`Not tabular`
#   (a).Records don't have to all have the same set of attributes
#
# 3.Data organized into `collections` of objects
#
# 4.Objects are collections of `attribute-value` pairs
#
# 5.`Nested JSON`: objects within objects
#
# ### Reading JSON Data
#
# `read_json()` :
#
# 1.Takes a `string path` to JSON _or_ JSON data as a string
#
# 2.Specify data types with `dtype` keyword argument
#
# 3.`orient` keyword argument to `flag` uncommon JSON data layouts
#
# ### Data Orientation
#
# JSON data isn't tabular, so there are ways to store data--
#
# 1.`Record Orientation` : Most common JSON arrangement
#
# 2.`Column Orientation` : More space-efficient than record-oriented JSON
#
# ### Load JSON data
#
# Many open data portals make available JSONs datasets that are particularly easy to parse. They can be accessed directly via `URL`. Each `object` is a `record`, all objects have the same set of attributes, and none of the values are nested objects that themselves need to be parsed.
#
# JSON isn't a tabular format, so pandas makes assumptions about its orientation when loading data. Most JSON data you encounter will be in orientations that pandas can automatically transform into a data frame.
#
# Sometimes, like in this `modified` version of the Department of Homeless Services Daily Report, data is `oriented differently`. To reduce the file size, it has been `split` formatted. You'll see what happens when you try to load it normally versus with the orient keyword argument. The `try/except` block will alert you if there are errors loading the data.

# %%
### Try loading dhs_report_reformatted.json without any keyword arguments.

try:
    # Load the JSON without keyword arguments
    df = pd.read_json("dhs_report_reformatted.json")
    
    # Plot total population in shelters over time
    df["date_of_census"] = pd.to_datetime(df["date_of_census"])
    df.plot(x="date_of_census", 
            y="total_individuals_in_shelter")
    plt.show()
    
except ValueError:
    print("pandas could not parse the JSON.")

# %%
### Load dhs_report_reformatted.json to a data frame with orient specified.

try:
    # Load the JSON with orient specified
    df = pd.read_json("dhs_report_reformatted.json",
                      orient = "split")
    
    # Plot total population in shelters over time
    df["date_of_census"] = pd.to_datetime(df["date_of_census"])
    df.plot(x="date_of_census", 
            y="total_individuals_in_shelter")
    plt.show()
    
except ValueError:
    print("pandas could not parse the JSON.")

# %% [markdown]
# ### Application Programming Interfaces(APIs)
#
# 1.Defines how an application `communicates` with other programs.
#
# 2.Way to get `data` from an `application` without knowing database details.
#
# ### Requests
#
# 1.Send and get data from websites
#
# 2.Not tied to a particular API
#
# 3.`requests.get()` to get data from a `URL`
#
# ### requests.get()
#
# 1.`requests.get(url_string)` to get data from a URL
#
# 2.Keyword arguments:
#
#   a.`params keyword`: takes a `dictionary` of `parameters and values` to customize API request
#
#   b.`headers keyword`: takes a `dictionary`, can be used to provide user `authentication` to API
#
# 3.Result: a `response` object, containing `data and metadata`
#
#   a.`response.json()` will return just the `JSON` data
#
# ### response.json() and pandas
#
# 1.`response.json()` returns a `dictionary`
#
# 2.`read_json()` expects `strings`, not `dictionaries`. Load the response JSON to a `data frame` with `pd.DataFrame()`. `read_json()` will give an `error!`

# %% [markdown]
# ### Ex 1: Get data from an API
#
# In this exercise, you'll use `requests.get()` to query the `Yelp Business Search API` for `cafes` in `New York City`. requests.get() needs a URL to get data from.
#
# `Formatting` parameters to get the data you need is an integral part of working with APIs. These parameters can be passed to the `get()` function's`params` keyword argument as a `dictionary`.
#
# Many `APIs` require users provide an `API key`, obtained by `registering` for the service. `Keys` typically are passed in the request `header`, rather than as parameters.
#
# The Yelp API also needs search parameters and authorization headers passed to the params and headers keyword arguments, respectively.
#
# The Yelp API requires the `location` parameter be set. It also lets users supply a term to search for. You'll use these parameters to get data about `cafes` in NYC, then process the result to create a data frame.
#
# The Yelp API documentation says "To authenticate API calls with the API Key, set the Authorization HTTP `header` value as Bearer API_KEY." The key is `api_key`.
#
# You'll need to extract the data from the response with its `json()` method, and pass it to pandas's `DataFrame()` function to make a data frame. Note that the necessary data is under the dictionary key `"businesses"`.
#
# In this exercise--
#
# 1.Copy the `URL` of Yelp Business Search API and store it in a variable `api_url`
#
# 2.Create a `dictionary`, `parameters`, with the `term` and `location` parameters set to search for `"cafe"`s in `"NYC"`.
#
# 3.Create a `dictionary`,`headers`, that passes the formatted key string to the `"Authorization"` header value.
#
# 4.`Query` the Yelp API `api_url` with `requests`'s `get()` function and the headers and params keyword arguments set. Save the result as `response`.
#
# 5.`Extract` the JSON data from response with the appropriate method. Save the result as `data`.
#
# 6.Load the cafe listings to the data frame `cafes` with pandas's DataFrame() function. The listings are under the `businesses"` key in data.
#
# 7.Print the data frame's `dtypes` to see what information you're getting.
#
# 8.Load the `"businesses"` values in data to the data frame cafes and print the head.
#
# 9.From the data frame cafes and print the `names` column.

# %%
# Go to the URL of Yelp Business Search API -- https://www.yelp.com/developers/documentation/v3/business_search

#  Get the API URL from the Request --- https://api.yelp.com/v3/businesses/search

api_url = "https://api.yelp.com/v3/businesses/search"

# %%
api_key = 'bRKybkEWy8-IR8mixB_OuWQBKUsKR-lHyjjCq19dSr3XXwcoOIGWmHvwbZnj8W4c7NiuciEevmynbL8eiLZkOy87GhUjTOw-rlmU9Ldm1A_89h8jRn9y2sO7709-YXYx'

# %%
## Create a dictionary, parameters, with the `term` and `location` parameters set to search for "cafe"s in "NYC"

parameters = {"term" : "cafe" , "location" : 'NYC'}

# %%
# Create a dictionary, headers, that passes the formatted key string to the "Authorization" header value. The key is api_key

headers = {"Authorization": "Bearer {}".format(api_key)}

# %%
# Query the Yelp API api_url with requests's get() function and the headers and params keyword arguments set. 
# Save the result as response.

response = requests.get(api_url, params = parameters, headers = headers)

# %%
## Extract the JSON data from response with the appropriate method. Save the result as data.

data = response.json()
data.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
## Load the cafe listings to the data frame cafes with pandas's DataFrame() function. 
## The listings are under the businesses" key in data.

cafes = pd.DataFrame(data["businesses"])


# Load the "businesses" values in data to the data frame cafes and print the head.
cafes.head()
# Out:
#                        id                                          alias  \
# 0  vijwGDNrPBJHEG7_DsjZNw                               usagi-ny-dumbo-7
# 1  pimuUR-TEHIjUla3S3jemQ  coffee-project-new-york-east-village-new-york
# 2  KWC_KYP336tSFhAihd8plg             bluestone-lane-dumbo-café-brooklyn
# 3  kpxXi23lUQkeJQH-2BtzDw                          qahwah-house-brooklyn
# 4  QgJE4Jfzk7nzmRF_W_6ASA                          espresso-bar-brooklyn
#
#                                      name  \
# 0                                Usagi NY
# 1  Coffee Project New York | East Village
# 2               Bluestone Lane DUMBO Café
# 3                            Qahwah House
# 4                            Espresso Bar
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/6yNqnk...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/oTalWA...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/AjXvAC...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/hGHi0N...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/LeLZYK...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/usagi-ny-dumbo-7?adju...            69
# 1  https://www.yelp.com/biz/coffee-project-new-yo...           695
# 2  https://www.yelp.com/biz/bluestone-lane-dumbo-...           201
# 3  https://www.yelp.com/biz/qahwah-house-brooklyn...           128
# 4  https://www.yelp.com/biz/espresso-bar-brooklyn...             2
#
#                                           categories  rating  \
# 0  [{'alias': 'bookstores', 'title': 'Bookstores'...     4.5
# 1  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 2  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0
# 3  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     5.0
# 4             [{'alias': 'cafes', 'title': 'Cafes'}]     5.0
#
#                                          coordinates        transactions  \
# 0     {'latitude': 40.70383, 'longitude': -73.98691}  [delivery, pickup]
# 1     {'latitude': 40.72699, 'longitude': -73.98922}          [delivery]
# 2  {'latitude': 40.70077577888819, 'longitude': -...  [delivery, pickup]
# 3  {'latitude': 40.7185628184474, 'longitude': -7...  [delivery, pickup]
# 4   {'latitude': 40.653054, 'longitude': -73.975948}                  []
#
#   price                                           location         phone  \
# 0    $$  {'address1': '163 Plymouth St', 'address2': ''...  +17188018037
# 1     $  {'address1': '239 E 5th St', 'address2': None,...  +12122287888
# 2     $  {'address1': '55 Prospect St', 'address2': '',...  +17183746858
# 3     $  {'address1': '162 Bedford Ave', 'address2': ''...
# 4   NaN  {'address1': '1233 Prospect Ave', 'address2': ...
#
#     display_phone     distance
# 0  (718) 801-8037   635.781863
# 1  (212) 228-7888  2438.032688
# 2  (718) 374-6858   720.691039
# 3                  3455.274392
# 4                  6021.998285

# %%
## Print the data frame's dtypes to see what information you're getting.

cafes.dtypes
# Out:
# id                object
# alias             object
# name              object
# image_url         object
# is_closed           bool
# url               object
# review_count       int64
# categories        object
# rating           float64
# coordinates       object
# transactions      object
# price             object
# location          object
# phone             object
# display_phone     object
# distance         float64
# dtype: object

# %%
## From the data frame cafes and print the name column.

cafes["name"]
# Out:
# 0                                   Usagi NY
# 1     Coffee Project New York | East Village
# 2                  Bluestone Lane DUMBO Café
# 3                               Qahwah House
# 4                               Espresso Bar
# 5                                  % Arabica
# 6                                     Butler
# 7                           Good Thanks Cafe
# 8                                     Banter
# 9                             Urban Backyard
# 10                                  Devocion
# 11                      Remi Flower & Coffee
# 12                       Now or Never Coffee
# 13                              Sweet Moment
# 14                              Bibble & Sip
# 15                                      ACRE
# 16                            AMERICANO CAFE
# 17                          Hole in the Wall
# 18                                     Maman
# 19                          FEED Shop & Cafe
# Name: name, dtype: object

# %% [markdown]
# ### Working with nested JSONs
#
# JSONs contain `objects` with `attribute-value` pair. A JSON is nested when the `value` itself is an `object`.
#
# ### Flatten nested JSONs
#
# A feature of JSON data is that it can be `nested`: that means in this case, an `attribute`'s `value` can consist of `attribute-value` pairs. This nested data is more useful `unpacked, or flattened`, into its own `data frame` columns. The `pandas.io.json` submodule has a function, `json_normalize()`, that does exactly this.
#
# `pandas.io.json`:
#
# 1.`pandas.io.json` submodule has tools for `reading and writing` JSON. It Needs its own `import` statement.
#
# 2.`json_normalize()`:
#
#   a.Takes a `dictionary/list` of dictionaries (like pd.DataFrame() does)
#
#   b.Returns a `flattened` dataframe
#
#   c.Default flattened column name pattern: `attribute.nestedattribute`
#
#   d.Choose a different separator with the `sep` argument
#
#
# ### Ex 2:
#
# The Yelp API `response` data is nested. Your job is to `flatten` out the next level of data in the `coordinates` and `location` columns.
#
# 1.Load the `json_normalize()` function from `pandas.io.json` submodule.
#
# 2.Isolate the JSON data from `response` and assign it to `data`
#
# 3.Use `json_normalize()` to flatten and load the `businesses` data to a data frame, `cafes`. Set the `sep` argument to use underscores `(_)`, rather than periods.

# %%
# Load the json_normalize() function from pandas.io.json submodule.
from pandas import json_normalize

# %%
# .Isolate the JSON data from response and assign it to data

data = response.json()

# %%
# Use json_normalize() to flatten and load the businesses data to a data frame, cafes. 
# Set the sep argument to use underscores (_), rather than periods.

cafes = json_normalize(data["businesses"], sep = "_")
#cafes

# %%
# Out:
# {'id': 'vijwGDNrPBJHEG7_DsjZNw',
#  'alias': 'usagi-ny-dumbo-7',
#  'name': 'Usagi NY',
#  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6yNqnkPDJAZXpMemwCYN3w/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/usagi-ny-dumbo-7?adjust_creative=kCAx88XpjKpjxe9YMRbcwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kCAx88XpjKpjxe9YMRbcwg',
#  'review_count': 69,
#  'categories': [{'alias': 'bookstores', 'title': 'Bookstores'},
#   {'alias': 'cafes', 'title': 'Cafes'},
#   {'alias': 'homedecor', 'title': 'Home Decor'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 40.70383, 'longitude': -73.98691},
#  'transactions': ['delivery', 'pickup'],
#  'price': '$$',
#  'location': {'address1': '163 Plymouth St',
#   'address2': '',
#   'address3': '',
#   'city': 'Dumbo',
#   'zip_code': '11201',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['163 Plymouth St', 'Dumbo, NY 11201']},
#  'phone': '+17188018037',
#  'display_phone': '(718) 801-8037',
#  'distance': 635.7818631527628}

# %% [markdown]
# ### Deeply Nested Data
#
# `json_normalize()`:
#
#  a.`record_path`: string/list of string attributes to nested data
#
#  b.`meta`: list of other attributes to load to data frame
#
#  c.`meta_prefix`: string to prefix to meta column names
#
# Last exercise, you flattened data nested down one level. Here, you'll unpack more deeply nested data. The `categories` attribute in the `Yelp API response` contains `lists` of objects. To flatten this data, you'll employ `json_normalize()` arguments to specify the `path` to `categories` and pick other `attributes` to `include` in the data frame. You should also change the `separator` to facilitate column selection and `prefix` the other attributes to `prevent` column name `collisions`.
#
# ### Ex 3:
#
# Use `json_normalize()`:
#
# 1.to flatten records under the `businesses` key in data, setting `underscores (_)` as separators,
#
# 2.Specify the `record_path` to the `categories` data,
#
# 3.Set the `meta` keyword argument to get business `name`, `alias`, `rating`, and the `attributes` nested under `coordinates: latitude and longitude`,
#
# 4.Add `"biz_"` as a `meta_prefix` to prevent `duplicate` column names.

# %%
data["businesses"][0]
# Out:
# {'id': 'vijwGDNrPBJHEG7_DsjZNw',
#  'alias': 'usagi-ny-dumbo-7',
#  'name': 'Usagi NY',
#  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6yNqnkPDJAZXpMemwCYN3w/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/usagi-ny-dumbo-7?adjust_creative=kCAx88XpjKpjxe9YMRbcwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kCAx88XpjKpjxe9YMRbcwg',
#  'review_count': 69,
#  'categories': [{'alias': 'bookstores', 'title': 'Bookstores'},
#   {'alias': 'cafes', 'title': 'Cafes'},
#   {'alias': 'homedecor', 'title': 'Home Decor'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 40.70383, 'longitude': -73.98691},
#  'transactions': ['delivery', 'pickup'],
#  'price': '$$',
#  'location': {'address1': '163 Plymouth St',
#   'address2': '',
#   'address3': '',
#   'city': 'Dumbo',
#   'zip_code': '11201',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['163 Plymouth St', 'Dumbo, NY 11201']},
#  'phone': '+17188018037',
#  'display_phone': '(718) 801-8037',
#  'distance': 635.7818631527628}

# %%
flat_cafes = json_normalize(data["businesses"], sep="_", record_path='categories',
                            
                            meta=["name","alias", "rating", ['coordinates', "latitude"],['coordinates', "longitude"]],
                            
                            meta_prefix = "cafe_")

# %%
flat_cafes.head()
# Out:
#         alias         title                               cafe_name  \
# 0  bookstores    Bookstores                                Usagi NY
# 1       cafes         Cafes                                Usagi NY
# 2   homedecor    Home Decor                                Usagi NY
# 3      coffee  Coffee & Tea  Coffee Project New York | East Village
# 4  sandwiches    Sandwiches  Coffee Project New York | East Village
#
#                                       cafe_alias cafe_rating  \
# 0                               usagi-ny-dumbo-7         4.5
# 1                               usagi-ny-dumbo-7         4.5
# 2                               usagi-ny-dumbo-7         4.5
# 3  coffee-project-new-york-east-village-new-york         4.5
# 4  coffee-project-new-york-east-village-new-york         4.5
#
#   cafe_coordinates_latitude cafe_coordinates_longitude
# 0                  40.70383                  -73.98691
# 1                  40.70383                  -73.98691
# 2                  40.70383                  -73.98691
# 3                  40.72699                  -73.98922
# 4                  40.72699                  -73.98922

# %% [markdown]
# ### Appending two dataframes
#
# In this exercise, you’ll practice appending records by creating a dataset of the 100 highest-rated cafes in New York City according to Yelp.
#
# APIs often limit the amount of data returned, since sending large datasets can be time- and resource-intensive. The Yelp Business Search API limits the results returned in a call to 50 records. However, the offset parameter lets a user retrieve results starting after a specified number. By modifying the offset, we can get results 1-50 in one call and 51-100 in another. Then, we can append the data frames.
#
# Append the results of the API call to top_50_cafes, setting ignore_index so rows will be renumbered.

# %%
params = {"term": "cafe", 
          "location": "NYC",
          "sort_by": "rating", 
          "limit": 50,
          }

# %%
result = requests.get(api_url, headers=headers, params=params)
first_50_cafes = json_normalize(result.json()["businesses"])

# %%
first_50_cafes
# Out:
#                         id                                          alias  \
# 0   vijwGDNrPBJHEG7_DsjZNw                               usagi-ny-dumbo-7
# 1   kpxXi23lUQkeJQH-2BtzDw                          qahwah-house-brooklyn
# 2   pimuUR-TEHIjUla3S3jemQ  coffee-project-new-york-east-village-new-york
# 3   KWC_KYP336tSFhAihd8plg             bluestone-lane-dumbo-café-brooklyn
# 4   QgJE4Jfzk7nzmRF_W_6ASA                          espresso-bar-brooklyn
# 5   ED7A7vDdg8yLNKJTSVHHmg                               arabica-brooklyn
# 6   -2UtjTxrt1Xzd-HPsLJ7mA                              butler-brooklyn-2
# 7   vZevXSC1w27dEvXc2EHCEg                      good-thanks-cafe-new-york
# 8   Zc7Jbuwe3XO-EaVXIh_TYQ                                banter-new-york
# 9   HUlbrPvAr6sXuBfp5z1MWA                        urban-backyard-new-york
# 10  jZZMmT7Mk3S-fNjXcq3Ksg                            devocion-brooklyn-4
# 21  https://www.yelp.com/biz/hvrminn-new-york-5?ad...             1
# 22  https://www.yelp.com/biz/kona-coffee-and-compa...           164
# 23  https://www.yelp.com/biz/citizens-of-soho-new-...            39
# 24  https://www.yelp.com/biz/round-k-by-sol-new-yo...            37
# 25  https://www.yelp.com/biz/burrow-brooklyn?adjus...            81
# 26  https://www.yelp.com/biz/butler-brooklyn-3?adj...             9
# 27  https://www.yelp.com/biz/porcelain-ridgewood?a...            36
# 28  https://www.yelp.com/biz/pause-cafe-new-york?a...           437
# 29  https://www.yelp.com/biz/rosecrans-new-york?ad...            44
# 30  https://www.yelp.com/biz/devocion-new-york?adj...           127
# 31  https://www.yelp.com/biz/reunion-brooklyn-2?ad...           490
# 32  https://www.yelp.com/biz/vineapple-cafe-brookl...            60
# 33  https://www.yelp.com/biz/sey-coffee-brooklyn?a...           123
# 34  https://www.yelp.com/biz/book-club-new-york?ad...            50
# 35  https://www.yelp.com/biz/ppl-brooklyn?adjust_c...            19
# 36  https://www.yelp.com/biz/brain-food-the-smart-...             8
# 37  https://www.yelp.com/biz/butler-brooklyn?adjus...           126
# 38  https://www.yelp.com/biz/absolute-coffee-brook...           199
# 39  https://www.yelp.com/biz/koneko-new-york-3?adj...           303
# 40  https://www.yelp.com/biz/grace-street-new-york...          2767
# 41  https://www.yelp.com/biz/blackstone-coffee-roa...           102
# 42  https://www.yelp.com/biz/desert-rose-cafe-new-...             6
# 43  https://www.yelp.com/biz/white-noise-coffee-co...           100
# 44  https://www.yelp.com/biz/maman-new-york-19?adj...            36
# 45  https://www.yelp.com/biz/devocion-brooklyn-3?a...           111
# 46  https://www.yelp.com/biz/davelle-new-york-2?ad...           190
# 47  https://www.yelp.com/biz/banter-new-york-3?adj...            80
# 48  https://www.yelp.com/biz/maman-new-york-20?adj...           318
# 49  https://www.yelp.com/biz/society-cafe-new-york...           194
#
#                                            categories  rating  \
# 0   [{'alias': 'bookstores', 'title': 'Bookstores'...     4.5
# 1   [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     5.0
# 2   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 3   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0
# 4              [{'alias': 'cafes', 'title': 'Cafes'}]     5.0
# 5      [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     4.0
# 6   [{'alias': 'bakeries', 'title': 'Bakeries'}, {...     4.5
# 7   [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     4.5
# 8   [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 9      [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     4.5
# 10  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0
# 11  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 12     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     5.0
# 13  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 14  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 15  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 16  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     5.0
# 17  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0
# 18  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     4.0
# 19  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0
# 20  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 21     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     5.0
# 22  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 23  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     4.0
# 24             [{'alias': 'cafes', 'title': 'Cafes'}]     4.5
# 25  [{'alias': 'desserts', 'title': 'Desserts'}, {...     4.5
# 26  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     4.5
# 27  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     4.5
# 28  [{'alias': 'moroccan', 'title': 'Moroccan'}, {...     4.5
# 29  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     4.5
# 30  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     4.0
# 31  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 32  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 33  [{'alias': 'coffeeroasteries', 'title': 'Coffe...     4.5
# 34  [{'alias': 'bookstores', 'title': 'Bookstores'...     4.5
# 35     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     5.0
# 36  [{'alias': 'juicebars', 'title': 'Juice Bars &...     4.0
# 37  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...     4.5
# 38  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 39  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 40  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0
# 41  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     5.0
# 42  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     5.0
# 43     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     4.5
# 44  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     4.0
# 45  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0
# 46  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 47  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 48  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0
# 49  [{'alias': 'newamerican', 'title': 'American (...     4.0
#
#           transactions  ... coordinates.latitude coordinates.longitude  \
# 0   [delivery, pickup]  ...            40.703830            -73.986910
# 1   [delivery, pickup]  ...            40.718563            -73.957130
# 2           [delivery]  ...            40.726990            -73.989220
# 3   [delivery, pickup]  ...            40.700776            -73.988364
# 4                   []  ...            40.653054            -73.975948
# 5                   []  ...            40.702471            -73.994260
# 6   [delivery, pickup]  ...            40.703267            -73.992242
# 7   [delivery, pickup]  ...            40.719720            -73.989520
# 8   [delivery, pickup]  ...            40.727870            -74.001100
# 9           [delivery]  ...            40.720770            -73.996460
# 10          [delivery]  ...            40.716054            -73.964684
# 11                  []  ...            40.753781            -73.968999
# 12          [delivery]  ...            40.722950            -74.004560
# 13  [delivery, pickup]  ...            40.717630            -73.997140
# 14  [delivery, pickup]  ...            40.762836            -73.985180
# 15  [delivery, pickup]  ...            40.726330            -73.954710
# 16  [delivery, pickup]  ...            40.629624            -74.073889
# 17  [delivery, pickup]  ...            40.744460            -73.971940
# 18                  []  ...            40.720280            -73.998400
# 19          [delivery]  ...            40.703402            -73.991410
# 20  [delivery, pickup]  ...            40.714954            -73.959786
# 21                  []  ...            40.703080            -73.983920
# 22  [delivery, pickup]  ...            40.725870            -73.989880
# 23  [delivery, pickup]  ...            40.721346            -73.997669
# 24                  []  ...            40.715146            -73.993134
# 25          [delivery]  ...            40.702722            -73.986888
# 26                  []  ...            40.719788            -73.959144
# 27  [delivery, pickup]  ...            40.702315            -73.901679
# 28  [delivery, pickup]  ...            40.721230            -73.984080
# 29          [delivery]  ...            40.734217            -73.999848
# 30          [delivery]  ...            40.739040            -73.989160
# 31  [delivery, pickup]  ...            40.717100            -73.951640
# 32  [delivery, pickup]  ...            40.698297            -73.993076
# 33          [delivery]  ...            40.705320            -73.932400
# 34                  []  ...            40.723015            -73.983207
# 35                  []  ...            40.712885            -73.958529
# 36  [delivery, pickup]  ...            40.690541            -73.991635
# 37                  []  ...            40.711767            -73.964692
# 38          [delivery]  ...            40.688270            -73.987569
# 39          [delivery]  ...            40.720440            -73.984120
# 40  [delivery, pickup]  ...            40.747858            -73.986559
# 41  [delivery, pickup]  ...            40.733290            -74.006190
# 42  [delivery, pickup]  ...            40.728280            -73.985320
# 43          [delivery]  ...            40.689624            -73.988249
# 44  [delivery, pickup]  ...            40.728534            -74.007779
# 45          [delivery]  ...            40.688570            -73.983340
# 46  [delivery, pickup]  ...            40.718520            -73.986050
# 47  [delivery, pickup]  ...            40.739135            -74.005738
# 48  [delivery, pickup]  ...            40.743250            -73.990230
# 49  [delivery, pickup]  ...            40.736180            -73.996596
#
#        location.address1  location.address2  location.address3  location.city  \
# 0        163 Plymouth St                                                Dumbo
# 1        162 Bedford Ave                                  None       Brooklyn
# 2           239 E 5th St               None                          New York
# 3         55 Prospect St                                  None       Brooklyn
# 4      1233 Prospect Ave                                  None       Brooklyn
# 5       20 Old Fulton St                                  None       Brooklyn
# 6            40 Water St                                  None       Brooklyn
# 7        131A Orchard St               None               None       New York
# 8        169 Sullivan St                                  None       New York
# 9        180 Mulberry St               None                          New York
# 10           69 Grand St               None                          Brooklyn
# 11           906 2nd Ave                                  None       New York
# 12           30 Grand St               None                          New York
# 13           106 Mott St               None                          New York
# 14         253 W 51st St                                             New York
# 15       64 Meserole Ave               None                          Brooklyn
# 16        7 Navy Pier Ct               None               None  STATEN ISLAND
# 17         445 E 35th St               None                          New York
# 18         239 Centre St               None                          New York
# 19           55 Water St                                  None       Brooklyn
# 20  232 Metropolitan Ave                                             Brooklyn
# 21          247 Water St            Ste 104                          New York
# 22            57 2nd Ave                                  None       New York
# 23      201 Lafayette St                                  None       New York
# 24           78 Canal St                                  None       New York
# 25             68 Jay St            Ste 119                          Brooklyn
# 26          101 N 8th St               None                          Brooklyn
# 27      880 Woodward Ave               None                         Ridgewood
# 28          3 Clinton St                                             New York
# 29       7 Greenwich Ave                                  None       New York
# 30          25 E 20th St                                  None       New York
# 31         544 Union Ave                                             Brooklyn
# 32       71 Pineapple St                                             Brooklyn
# 33         18 Grattan St               None                          Brooklyn
# 34          197 E 3rd St               None                          New York
# 35       189 Roebling St                                  None       Brooklyn
# 36          111 Court St                                  None       Brooklyn
# 37           95 S 5th St               None               None       Brooklyn
# 38      327 Atlantic Ave               None                          Brooklyn
# 39         26 Clinton St                                             New York
# 40          17 W 32nd St               None                          New York
# 41         502 Hudson St                                  None       New York
# 42          350 E 9th St                                  None       New York
# 43           57 Smith St                                  None       Brooklyn
# 44         375 Hudson St               None                          New York
# 45     276 Livingston St                                  None       Brooklyn
# 46        102 Suffolk St                                  None       New York
# 47         643 Hudson St                                  None       New York
# 48          22 W 25th St               None                          New York
# 49          52 W 13th St               None                          New York
#
#    location.zip_code location.country location.state  \
# 0              11201               US             NY
# 1              11249               US             NY
# 2              10003               US             NY
# 3              11201               US             NY
# 4              11218               US             NY
# 5              11201               US             NY
# 6              11201               US             NY
# 7              10002               US             NY
# 8              10012               US             NY
# 9              10012               US             NY
# 10             11249               US             NY
# 11             10017               US             NY
# 12             10013               US             NY
# 13             10013               US             NY
# 14             10019               US             NY
# 15             11222               US             NY
# 16             10304               US             NY
# 17             10016               US             NY
# 18             10013               US             NY
# 19             11201               US             NY
# 20             11211               US             NY
# 21             11201               US             NY
# 22             10003               US             NY
# 23             10012               US             NY
# 24             10002               US             NY
# 25             11201               US             NY
# 26             11249               US             NY
# 27             11385               US             NY
# 28             10002               US             NY
# 29             10014               US             NY
# 30             10003               US             NY
# 31             11211               US             NY
# 32             11201               US             NY
# 33             11206               US             NY
# 34             10009               US             NY
# 35             11211               US             NY
# 36             11201               US             NY
# 37             11249               US             NY
# 38             11201               US             NY
# 39             10002               US             NY
# 40             10001               US             NY
# 41             10014               US             NY
# 42             10003               US             NY
# 43             11201               US             NY
# 44             10014               US             NY
# 45             11201               US             NY
# 46             10002               US             NY
# 47             10014               US             NY
# 48             10010               US             NY
# 49             10011               US             NY
#
#                        location.display_address
# 0            [163 Plymouth St, Dumbo, NY 11201]
# 1         [162 Bedford Ave, Brooklyn, NY 11249]
# 2            [239 E 5th St, New York, NY 10003]
# 3          [55 Prospect St, Brooklyn, NY 11201]
# 4       [1233 Prospect Ave, Brooklyn, NY 11218]
# 5        [20 Old Fulton St, Brooklyn, NY 11201]
# 6             [40 Water St, Brooklyn, NY 11201]
# 7         [131A Orchard St, New York, NY 10002]
# 8         [169 Sullivan St, New York, NY 10012]
# 9         [180 Mulberry St, New York, NY 10012]
# 10            [69 Grand St, Brooklyn, NY 11249]
# 11            [906 2nd Ave, New York, NY 10017]
# 12            [30 Grand St, New York, NY 10013]
# 13            [106 Mott St, New York, NY 10013]
# 14          [253 W 51st St, New York, NY 10019]
# 15        [64 Meserole Ave, Brooklyn, NY 11222]
# 16    [7 Navy Pier Ct, STATEN ISLAND, NY 10304]
# 17          [445 E 35th St, New York, NY 10016]
# 18          [239 Centre St, New York, NY 10013]
# 19            [55 Water St, Brooklyn, NY 11201]
# 20   [232 Metropolitan Ave, Brooklyn, NY 11211]
# 21  [247 Water St, Ste 104, New York, NY 11201]
# 22             [57 2nd Ave, New York, NY 10003]
# 23       [201 Lafayette St, New York, NY 10012]
# 24            [78 Canal St, New York, NY 10002]
# 25     [68 Jay St, Ste 119, Brooklyn, NY 11201]
# 26           [101 N 8th St, Brooklyn, NY 11249]
# 27      [880 Woodward Ave, Ridgewood, NY 11385]
# 28           [3 Clinton St, New York, NY 10002]
# 29        [7 Greenwich Ave, New York, NY 10014]
# 30           [25 E 20th St, New York, NY 10003]
# 31          [544 Union Ave, Brooklyn, NY 11211]
# 32        [71 Pineapple St, Brooklyn, NY 11201]
# 33          [18 Grattan St, Brooklyn, NY 11206]
# 34           [197 E 3rd St, New York, NY 10009]
# 35        [189 Roebling St, Brooklyn, NY 11211]
# 36           [111 Court St, Brooklyn, NY 11201]
# 37            [95 S 5th St, Brooklyn, NY 11249]
# 38       [327 Atlantic Ave, Brooklyn, NY 11201]
# 39          [26 Clinton St, New York, NY 10002]
# 40           [17 W 32nd St, New York, NY 10001]
# 41          [502 Hudson St, New York, NY 10014]
# 42           [350 E 9th St, New York, NY 10003]
# 43            [57 Smith St, Brooklyn, NY 11201]
# 44          [375 Hudson St, New York, NY 10014]
# 45      [276 Livingston St, Brooklyn, NY 11201]
# 46         [102 Suffolk St, New York, NY 10002]
# 47          [643 Hudson St, New York, NY 10014]
# 48           [22 W 25th St, New York, NY 10010]
# 49           [52 W 13th St, New York, NY 10011]
#
# [50 rows x 24 columns]

# %%
params2 = {"term": "cafe", 
          "location": "NYC",
          "sort_by": "rating", 
          "limit": 50,
          "offset": 50}

# %%
result = requests.get(api_url, headers=headers, params=params2)
next_50_cafes = json_normalize(result.json()["businesses"])

# %%
next_50_cafes
# Out:
#                         id                                        alias  \
# 0   VLC2DROxvGX-ka_aBmJN9w                   social-house-cafe-brooklyn
# 1   XEdGYktN7VVuyjkN5ukr4A                       bright-side-brooklyn-3
# 2   jniZaiTDALOVQfNkg_S9gg                        787-coffee-new-york-5
# 3   blX8Y6O0J4p6fXVcTRmANg                             the-elk-new-york
# 4   NJay-xUEFsvWzdeohs9EEA                    the-coppola-cafe-new-york
# 5   nI9a2XEe0kM6sEBZr-gxXg                   three-owls-market-new-york
# 6   u0bYCPlbJ85_lDjnZQ_e3w                 kaigo-coffee-room-new-york-4
# 7   1fDtQij01Mk92ZTGn6WHjg          the-little-sweet-cafe-boerum-hill-2
# 8   xTnivXEdEtXrnhp-z4JGvg                     la-parisienne-new-york-5
# 16  https://www.yelp.com/biz/cafe-ubani-new-york?a...            27
# 17  https://www.yelp.com/biz/kabisera-new-york-4?a...           103
# 18  https://www.yelp.com/biz/saltwater-coffee-new-...            39
# 19  https://www.yelp.com/biz/semicolon-cafe-jersey...           155
# 20  https://www.yelp.com/biz/brooklyn-kolache-broo...           339
# 21  https://www.yelp.com/biz/cafe-gitane-brooklyn?...            22
# 22  https://www.yelp.com/biz/partners-coffee-long-...           176
# 23  https://www.yelp.com/biz/cafefornia-coffee-sho...            10
# 24  https://www.yelp.com/biz/little-canal-new-york...           131
# 25  https://www.yelp.com/biz/cafe-sandra-new-york-...             7
# 26  https://www.yelp.com/biz/kaigo-coffee-room-bro...            61
# 27  https://www.yelp.com/biz/outro-new-york?adjust...           343
# 28  https://www.yelp.com/biz/harbs-soho-new-york-3...           154
# 29  https://www.yelp.com/biz/mud-new-york-3?adjust...          1227
# 30  https://www.yelp.com/biz/neighbors-brooklyn?ad...            30
# 31  https://www.yelp.com/biz/calyer-brooklyn-2?adj...            34
# 32  https://www.yelp.com/biz/perk-kafe-new-york?ad...           408
# 33  https://www.yelp.com/biz/tokuyama-salon-caf%C3...            52
# 34  https://www.yelp.com/biz/hole-in-the-wall-new-...           630
# 35  https://www.yelp.com/biz/in-common-nyc-new-yor...            13
# 36  https://www.yelp.com/biz/787-coffee-new-york-8...             4
# 37  https://www.yelp.com/biz/sunflower-gramercy-ne...           187
# 38  https://www.yelp.com/biz/semicolon-cafe-new-yo...            59
# 39  https://www.yelp.com/biz/meno-coffee-and-tea-n...            36
# 40  https://www.yelp.com/biz/octavia-coffee-brookl...             7
# 41  https://www.yelp.com/biz/bread-and-spread-dumb...           166
# 42  https://www.yelp.com/biz/three-jewels-cafe-new...            16
# 43  https://www.yelp.com/biz/black-star-bakery-and...           134
# 44  https://www.yelp.com/biz/bakeri-brooklyn?adjus...           384
# 45  https://www.yelp.com/biz/cafe-flor-new-york-2?...            22
# 46  https://www.yelp.com/biz/poetica-coffee-brookl...            21
# 47  https://www.yelp.com/biz/citizens-of-chelsea-n...           817
# 48  https://www.yelp.com/biz/kitsby-brooklyn?adjus...           226
# 49  https://www.yelp.com/biz/coffee-project-new-yo...            14
#
#                                            categories  rating  \
# 0   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     5.0
# 1              [{'alias': 'cafes', 'title': 'Cafes'}]     4.5
# 2   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     5.0
# 3   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0
# 4              [{'alias': 'cafes', 'title': 'Cafes'}]     4.5
# 5   [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     4.5
# 6   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 7      [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     4.5
# 8   [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     4.5
# 9   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     5.0
# 10  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...     4.5
# 11  [{'alias': 'australian', 'title': 'Australian'...     4.0
# 12  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...     4.5
# 13  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 14  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 15     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     5.0
# 16  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     5.0
# 17  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 18     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     4.5
# 19  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 20  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 21  [{'alias': 'moroccan', 'title': 'Moroccan'}, {...     4.5
# 22     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     4.0
# 23     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     4.0
# 24  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0
# 25             [{'alias': 'cafes', 'title': 'Cafes'}]     4.5
# 26     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     4.5
# 27  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     4.0
# 28  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...     4.0
# 29  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0
# 30  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     2.5
# 31  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     5.0
# 32  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 33  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 34  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 35             [{'alias': 'cafes', 'title': 'Cafes'}]     5.0
# 36     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     5.0
# 37  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 38  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     5.0
# 39  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 40  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     5.0
# 41  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 42  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     4.5
# 43  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...     4.0
# 44  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0
# 45  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 46     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     4.5
# 47  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0
# 48  [{'alias': 'desserts', 'title': 'Desserts'}, {...     4.5
# 49  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
#
#           transactions  ... coordinates.longitude     location.address1  \
# 0   [delivery, pickup]  ...            -73.966014           60 Broadway
# 1   [delivery, pickup]  ...            -73.964017          184 Kent Ave
# 2   [delivery, pickup]  ...            -74.010830           66 Pearl St
# 3           [delivery]  ...            -74.007479        128 Charles St
# 4   [delivery, pickup]  ...            -74.001612       171 West 4th St
# 5   [delivery, pickup]  ...            -74.008200     800 Washington St
# 6           [delivery]  ...            -74.000473     120C Lafayette St
# 7           [delivery]  ...            -73.986732           77B Hoyt St
# 8   [delivery, pickup]  ...            -74.009380           9 Maiden Ln
# 9   [delivery, pickup]  ...            -74.002048     112 Greenwich Ave
# 10  [delivery, pickup]  ...            -74.002316          223 Front St
# 11  [delivery, pickup]  ...            -73.981488           362 2nd Ave
# 12  [delivery, pickup]  ...            -73.988733       72 E 1st Street
# 13  [delivery, pickup]  ...            -73.973530           708 3rd Ave
# 14  [delivery, pickup]  ...            -73.961840          155 S 4th St
# 15  [delivery, pickup]  ...            -73.995257          54W Henry St
# 16  [delivery, pickup]  ...            -74.004170        37A Bedford St
# 17  [delivery, pickup]  ...            -73.989913          151 Allen St
# 18          [delivery]  ...            -73.999850        126 Waverly Pl
# 19  [delivery, pickup]  ...            -74.034801          77 Hudson St
# 20  [delivery, pickup]  ...            -73.955648        520 Dekalb Ave
# 21  [delivery, pickup]  ...            -73.981281         70 Hudson Ave
# 22  [delivery, pickup]  ...            -73.941600     26-25 Jackson Ave
# 23          [delivery]  ...            -73.971956        360 Myrtle Ave
# 24  [delivery, pickup]  ...            -73.990417           26 Canal St
# 25  [delivery, pickup]  ...            -73.983500           194 1st Ave
# 26          [delivery]  ...            -74.001017    139 Bridge Park Dr
# 27  [delivery, pickup]  ...            -73.991060          816 Broadway
# 28          [delivery]  ...            -74.000015        465 W Broadway
# 29                  []  ...            -73.986680          307 E 9th St
# 30          [delivery]  ...            -73.995539          60 Furman St
# 31  [delivery, pickup]  ...            -73.963940        519 Myrtle Ave
# 32  [delivery, pickup]  ...            -73.977041         162 E 37th St
# 33  [delivery, pickup]  ...            -73.980200          627 E 6th St
# 34  [delivery, pickup]  ...            -74.005630           15 Cliff St
# 35                  []  ...            -73.996220           441 9th Ave
# 36                  []  ...            -73.983966         319 E 14th St
# 37  [delivery, pickup]  ...            -73.982190           335 3rd Ave
# 38  [delivery, pickup]  ...            -73.945220  9 Edward M Morgan Pl
# 39  [delivery, pickup]  ...            -73.999053       218 Thompson St
# 40                  []  ...            -73.993819          198 Court St
# 41  [delivery, pickup]  ...            -73.986912          151 Front St
# 42                  []  ...            -73.991190            5 E 3rd St
# 43  [delivery, pickup]  ...            -73.958035         2-10 50th Ave
# 44          [delivery]  ...            -73.960130         150 Wythe Ave
# 45  [delivery, pickup]  ...            -73.999120           218 8th Ave
# 46  [delivery, pickup]  ...            -73.992623          251 Smith St
# 47                  []  ...            -74.000569         401 W 25th St
# 48  [delivery, pickup]  ...            -73.960977          186 Grand St
# 49  [delivery, pickup]  ...            -73.997095           155 7th Ave
#
#     location.address2  location.address3     location.city location.zip_code  \
# 0                None                             Brooklyn             11249
# 1                None                             Brooklyn             11249
# 2                None                             New York             10004
# 3                                                 New York             10014
# 4                                   None          New York             10014
# 5                                   None          New York             10014
# 6                                   None          New York             10013
# 7                                              Boerum Hill             11201
# 8                None                             New York             10038
# 9                None               None          New York             10011
# 10                                                New York             10038
# 11               None                             New York             10010
# 12                                                New York             10003
# 13                                  None          New York             10017
# 14               None                             Brooklyn             11211
# 15               None                             New York             10002
# 16                                  None          New York             10014
# 17                           Store South          New York             10002
# 18               None                             New York             10011
# 19               None                          Jersey City             07302
# 20                                                Brooklyn             11205
# 21                                  None          Brooklyn             11201
# 22                                  None  Long Island City             11101
# 23               None               None          Brooklyn             11205
# 24                                  None          New York             10002
# 25               None                             New York             10009
# 26               None               None          Brooklyn             11201
# 27                                  None          New York             10003
# 28                                  None          New York             10012
# 29                                                New York             10003
# 30               Fl 1                             Brooklyn             11201
# 31               None                             Brooklyn             11205
# 32                                                New York             10016
# 33               None                             New York             10009
# 34                                                New York             10038
# 35                                  None          New York             10001
# 36                                  None          New York             10003
# 37                                  None          New York             10010
# 38               None                             New York             10032
# 39               None                             New York             10012
# 40                                  None          Brooklyn             11201
# 41               None                                Dumbo             11201
# 42               None               None          New York             10003
# 43                                  None  Long Island City             11101
# 44                                                Brooklyn             11211
# 45                                  None          New York             10011
# 46               None                             Brooklyn             11231
# 47                                  None          New York             10001
# 48               None                             Brooklyn             11211
# 49               None                             New York             10011
#
#    location.country location.state  \
# 0                US             NY
# 1                US             NY
# 2                US             NY
# 3                US             NY
# 4                US             NY
# 5                US             NY
# 6                US             NY
# 7                US             NY
# 8                US             NY
# 9                US             NY
# 10               US             NY
# 11               US             NY
# 12               US             NY
# 13               US             NY
# 14               US             NY
# 15               US             NY
# 16               US             NY
# 17               US             NY
# 18               US             NY
# 19               US             NJ
# 20               US             NY
# 21               US             NY
# 22               US             NY
# 23               US             NY
# 24               US             NY
# 25               US             NY
# 26               US             NY
# 27               US             NY
# 28               US             NY
# 29               US             NY
# 30               US             NY
# 31               US             NY
# 32               US             NY
# 33               US             NY
# 34               US             NY
# 35               US             NY
# 36               US             NY
# 37               US             NY
# 38               US             NY
# 39               US             NY
# 40               US             NY
# 41               US             NY
# 42               US             NY
# 43               US             NY
# 44               US             NY
# 45               US             NY
# 46               US             NY
# 47               US             NY
# 48               US             NY
# 49               US             NY
#
#                            location.display_address price
# 0                 [60 Broadway, Brooklyn, NY 11249]   NaN
# 1                [184 Kent Ave, Brooklyn, NY 11249]   NaN
# 2                 [66 Pearl St, New York, NY 10004]   NaN
# 3              [128 Charles St, New York, NY 10014]    $$
# 4             [171 West 4th St, New York, NY 10014]     $
# 5           [800 Washington St, New York, NY 10014]    $$
# 6           [120C Lafayette St, New York, NY 10013]    $$
# 7              [77B Hoyt St, Boerum Hill, NY 11201]    $$
# 8                 [9 Maiden Ln, New York, NY 10038]    $$
# 9           [112 Greenwich Ave, New York, NY 10011]   NaN
# 10               [223 Front St, New York, NY 10038]     $
# 11                [362 2nd Ave, New York, NY 10010]    $$
# 12            [72 E 1st Street, New York, NY 10003]    $$
# 13                [708 3rd Ave, New York, NY 10017]    $$
# 14               [155 S 4th St, Brooklyn, NY 11211]     $
# 15               [54W Henry St, New York, NY 10002]   NaN
# 16             [37A Bedford St, New York, NY 10014]   NaN
# 17  [151 Allen St, Store South, New York, NY 10002]    $$
# 18             [126 Waverly Pl, New York, NY 10011]   NaN
# 19            [77 Hudson St, Jersey City, NJ 07302]   NaN
# 20             [520 Dekalb Ave, Brooklyn, NY 11205]     $
# 21              [70 Hudson Ave, Brooklyn, NY 11201]   NaN
# 22  [26-25 Jackson Ave, Long Island City, NY 11101]    $$
# 23             [360 Myrtle Ave, Brooklyn, NY 11205]   NaN
# 24                [26 Canal St, New York, NY 10002]     $
# 25                [194 1st Ave, New York, NY 10009]   NaN
# 26         [139 Bridge Park Dr, Brooklyn, NY 11201]   NaN
# 27               [816 Broadway, New York, NY 10003]    $$
# 28             [465 W Broadway, New York, NY 10012]    $$
# 29               [307 E 9th St, New York, NY 10003]    $$
# 30         [60 Furman St, Fl 1, Brooklyn, NY 11201]    $$
# 31             [519 Myrtle Ave, Brooklyn, NY 11205]   NaN
# 32              [162 E 37th St, New York, NY 10016]     $
# 33               [627 E 6th St, New York, NY 10009]   NaN
# 34                [15 Cliff St, New York, NY 10038]    $$
# 35                [441 9th Ave, New York, NY 10001]   NaN
# 36              [319 E 14th St, New York, NY 10003]   NaN
# 37                [335 3rd Ave, New York, NY 10010]    $$
# 38       [9 Edward M Morgan Pl, New York, NY 10032]     $
# 39            [218 Thompson St, New York, NY 10012]    $$
# 40               [198 Court St, Brooklyn, NY 11201]   NaN
# 41                  [151 Front St, Dumbo, NY 11201]    $$
# 42                 [5 E 3rd St, New York, NY 10003]     $
# 43      [2-10 50th Ave, Long Island City, NY 11101]     $
# 44              [150 Wythe Ave, Brooklyn, NY 11211]     $
# 45                [218 8th Ave, New York, NY 10011]   NaN
# 46               [251 Smith St, Brooklyn, NY 11231]   NaN
# 47              [401 W 25th St, New York, NY 10001]    $$
# 48               [186 Grand St, Brooklyn, NY 11211]    $$
# 49                [155 7th Ave, New York, NY 10011]   NaN
#
# [50 rows x 24 columns]

# %%
# Append the results, setting ignore_index to renumber rows
cafes = first_50_cafes.append(next_50_cafes, ignore_index = True)

# %%
# Print shape of cafes
cafes.shape
# Out:
# (100, 24)

# %% [markdown]
# ### Merge:
#
# To do this, you'll merge two datasets with the DataFrame merge() method. The first,crosswalk, is a crosswalk between ZIP codes and Public Use Micro Data Sample Areas (PUMAs), which are aggregates of census tracts and correspond roughly to NYC neighborhoods. Then, you'll merge in pop_data, which contains 2016 population estimates for each PUMA.
#
# 1.Use the DataFrame method to merge cafes and crosswalk on location_zip_code and zipcode, respectively. Assign the result to cafes_with_pumas.
#
# 2.Merge pop_data into cafes_with_pumas on their puma fields. Save the result as cafes_with_pop.

# %%
# Merge crosswalk into cafes on their zip code fields
cafes_with_pumas = cafes.merge(crosswalk,
                left_on="location_zip_code", 
                right_on="zipcode")



# Merge pop_data into cafes_with_pumas on puma field
cafes_with_pop = cafes_with_pumas.merge(pop_data, on = "puma")

# View the data
print(cafes_with_pop.head())
