# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.image as img

# %%
image = img.imread("MNIST Image.JPG")

# %%
## Displaying the image
plt.figure(dpi=100)
plt.imshow(image)

# %%
image.shape
# Out:
# (482, 486, 3)
